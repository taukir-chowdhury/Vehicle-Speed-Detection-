# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-91874b305a32> in <module>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive/')
#
# /usr/local/lib/python3.7/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, use_metadata_server)
#     113       force_remount=force_remount,
#     114       timeout_ms=timeout_ms,
# --> 115       ephemeral=True)
#     116
#     117
#
# /usr/local/lib/python3.7/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, use_metadata_server, ephemeral)
#     133   if ephemeral:
#     134     _message.blocking_request(
# --> 135         'request_auth', request={'authType': 'dfs_ephemeral'}, timeout_sec=None)
#     136
#     137   mountpoint = _os.path.expanduser(mountpoint)
#
# ...

# %%
# %cd /content/drive/MyDrive/vehicle_speed/program
# !dir
# Out:
# /content/drive/MyDrive/vehicle_speed/program
# deep_sort	  SpeedTracker_v5.py  utils
# requirements.txt  SpeedTracker_v6.py  yolov5

# %%
# %pip install -r requirements.txt
# Out:
# ...
#      |████████████████████████████████| 97 kB 3.6 MB/s
# ...
#      |████████████████████████████████| 1.9 MB 35.4 MB/s
# ...
#      |████████████████████████████████| 64 kB 2.7 MB/s
# ...
#      |████████████████████████████████| 890 kB 35.7 MB/s
# ...
#      |████████████████████████████████| 829 kB 34.4 MB/s
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#      |████████████████████████████████| 155 kB 44.2 MB/s
# ...
#      |████████████████████████████████| 4.1 MB 30.4 MB/s
# ...
#      |████████████████████████████████| 4.1 MB 31.0 MB/s
# ...
#      |████████████████████████████████| 61 kB 7.8 MB/s
# ...
#      |████████████████████████████████| 3.3 MB 25.5 MB/s
# ...
#      |████████████████████████████████| 42 kB 886 kB/s
# ...
#      |████████████████████████████████| 11.2 MB 33.5 MB/s
# ...

# %%
# !python SpeedTracker_v6.py
# Out:
# deep_sort/deep/reid/torchreid/metrics/rank.py:12: UserWarning: Cython evaluation (very fast so highly recommended) is unavailable, now use python evaluation.
#   'Cython evaluation (very fast so highly recommended) is '
# ...
# requirements: beautifulsoup4==4.10.0 not found and is required by YOLOv5, attempting auto-update...
# ...
#   Using cached beautifulsoup4-4.10.0-py3-none-any.whl (97 kB)
# ...
#   Attempting uninstall: beautifulsoup4
#     Found existing installation: beautifulsoup4 4.6.3
#     Uninstalling beautifulsoup4-4.6.3:
#       Successfully uninstalled beautifulsoup4-4.6.3
# ...
#
# requirements: charset-normalizer==2.0.10 not found and is required by YOLOv5, attempting auto-update...
# ...
#   Using cached charset_normalizer-2.0.10-py3-none-any.whl (39 kB)
# ...
#   Attempting uninstall: charset-normalizer
#     Found existing installation: charset-normalizer 2.0.12
#     Uninstalling charset-normalizer-2.0.12:
#       Successfully uninstalled charset-normalizer-2.0.12
# ...
#
# ...

# %%
# !python SpeedTracker_v6.py
# Out:
# deep_sort/deep/reid/torchreid/metrics/rank.py:12: UserWarning: Cython evaluation (very fast so highly recommended) is unavailable, now use python evaluation.
#   'Cython evaluation (very fast so highly recommended) is '
# requirements: flake8==4.0.1 not found and is required by YOLOv5, attempting auto-update...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# markdown 3.3.6 requires importlib-metadata>=4.4; python_version < "3.10", but you have importlib-metadata 4.2.0 which is incompatible.
# ...
#   Using cached importlib_metadata-4.2.0-py3-none-any.whl (16 kB)
# ...
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib-metadata 4.10.1
#     Uninstalling importlib-metadata-4.10.1:
#       Successfully uninstalled importlib-metadata-4.10.1
# ...
#
# ...

# %%
# !python SpeedTracker_v6.py
# Out:
# deep_sort/deep/reid/torchreid/metrics/rank.py:12: UserWarning: Cython evaluation (very fast so highly recommended) is unavailable, now use python evaluation.
#   'Cython evaluation (very fast so highly recommended) is '
# requirements: flake8==4.0.1 not found and is required by YOLOv5, attempting auto-update...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# markdown 3.3.6 requires importlib-metadata>=4.4; python_version < "3.10", but you have importlib-metadata 4.2.0 which is incompatible.
# ...
#   Using cached importlib_metadata-4.2.0-py3-none-any.whl (16 kB)
# ...
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib-metadata 4.10.1
#     Uninstalling importlib-metadata-4.10.1:
#       Successfully uninstalled importlib-metadata-4.10.1
# ...
#
# ...
