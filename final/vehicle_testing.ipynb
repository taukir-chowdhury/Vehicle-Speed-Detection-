# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# %cd /content/drive/MyDrive/vehicle_test/program
# !dir
# Out:
# /content/drive/MyDrive/vehicle_test/program
# deep_sort     report.csv	       SpeedTracker.py		test.py
# logv1.txt     requirements_final.txt   SpeedTracker_testing.py	utils
# only_view.py  requirements.txt	       SpeedTracker_v2.py	yolov5
# __pycache__   SpeedTracker_editted.py  SpeedTracker_v3.py
# README.md     SpeedTracker_final.py    SpeedTracker_v4.py

# %%
# !python SpeedTracker_v4.py
# Out:
# deep_sort/deep/reid/torchreid/metrics/rank.py:12: UserWarning: Cython evaluation (very fast so highly recommended) is unavailable, now use python evaluation.
#   'Cython evaluation (very fast so highly recommended) is '
# ...
# requirements: beautifulsoup4==4.10.0 not found and is required by YOLOv5, attempting auto-update...
# ...
#   Attempting uninstall: beautifulsoup4
#     Found existing installation: beautifulsoup4 4.6.3
#     Uninstalling beautifulsoup4-4.6.3:
#       Successfully uninstalled beautifulsoup4-4.6.3
# ...
#
# requirements: charset-normalizer==2.0.10 not found and is required by YOLOv5, attempting auto-update...
# ...
#   Attempting uninstall: charset-normalizer
#     Found existing installation: charset-normalizer 2.0.12
#     Uninstalling charset-normalizer-2.0.12:
#       Successfully uninstalled charset-normalizer-2.0.12
# ...
#
# requirements: colorama==0.4.4 not found and is required by YOLOv5, attempting auto-update...
# ...
#
# ...

# %%
# !python SpeedTracker_v5.py
# Out:
# deep_sort/deep/reid/torchreid/metrics/rank.py:12: UserWarning: Cython evaluation (very fast so highly recommended) is unavailable, now use python evaluation.
#   'Cython evaluation (very fast so highly recommended) is '
# requirements: importlib-metadata==4.10.1 not found and is required by YOLOv5, attempting auto-update...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# flake8 4.0.1 requires importlib-metadata<4.3; python_version < "3.8", but you have importlib-metadata 4.10.1 which is incompatible.
# ...
#   Using cached importlib_metadata-4.10.1-py3-none-any.whl (17 kB)
# ...
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib-metadata 4.2.0
#     Uninstalling importlib-metadata-4.2.0:
#       Successfully uninstalled importlib-metadata-4.2.0
# ...
#
# ...
